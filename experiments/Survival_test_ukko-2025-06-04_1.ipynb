# %% [markdown]
# # The loss function (loghazard) has issues, so we need to look into that.
#
# **For now it might be good to use pytorch.loss**, which implements partial log liklihood and Weibull losses.
#
# ---
#
# ### **Context: Why Breslow’s Method?**
#
# In the Cox model, the **partial likelihood** is used to estimate the regression coefficients without specifying the baseline hazard function. However, when **ties** occur — that is, **multiple events happen at the same time point** — the original Cox partial likelihood (which assumes distinct event times) becomes problematic.
#
# This is where **Breslow’s method** comes in: it provides a way to **approximate the partial likelihood** in the presence of tied event times.
#
# ---
#
# ### **Breslow’s Approximation: The Idea**
#
# Suppose at time \( t_j \), **\( d_j \) individuals** experience the event (i.e., a tie). Let:
#
# - \( R_j \): the **risk set** just before time \( t_j \)
# - \( \beta \): the vector of regression coefficients
# - \( x_i \): covariate vector for individual \( i \)
#
# The **exact partial likelihood** for tied events is computationally intensive. Breslow proposed a simpler approximation:
#
# \[
# L_B(\beta) = \prod_{j} \frac{\exp\left( \sum_{i \in D_j} \beta^T x_i \right)}{\left[ \sum_{i \in R_j} \exp(\beta^T x_i) \right]^{d_j}}
# \]
#
# Where:
# - \( D_j \): the set of individuals who fail at time \( t_j \)
# - The denominator is raised to the power \( d_j \), treating the tied events as if they occurred **sequentially but with the same risk set**.
#
# ---
#
# ### **Interpretation**
#
# - **Numerator**: Product of exponentiated linear predictors for those who failed at \( t_j \)
# - **Denominator**: Risk set sum raised to the number of events — this is the **approximation** part
#
# This method **underestimates the denominator** slightly compared to the exact method, especially when the number of ties is large.
#
# ---
#
# ### **Comparison with Other Methods**
#
# | Method         | Accuracy with Ties | Computational Cost | Notes |
# |----------------|--------------------|--------------------|-------|
# | **Breslow**    | Low (for many ties) | Low                | Simple, fast |
# | **Efron**      | Higher              | Moderate           | Better approximation |
# | **Exact**      | Highest             | High               | Computationally expensive |
#
# ---
#
# ### **When to Use Breslow’s Method**
#
# - **Few ties**: Breslow is often sufficient and computationally efficient.
# - **Many ties**: Prefer **Efron’s method** or **exact partial likelihood**.
#
# ---

# %%
import torchsurv.loss.cox as tscox #import neg_partial_log_likelihood

# Own implementation (super simple, double check!). Assumes events are ordered already.

def naive_partial_likelihood(log_hazard, event_indicator, event_time):
    risk_set = torch.flip(torch.cumsum(torch.flip(torch.exp(log_hazard), [0]), dim=0), [0])
    partial_likelihood = torch.sum(log_hazard[event_indicator == 1] - torch.log(risk_set[event_indicator == 1]))
    return partial_likelihood

def breslow_partial_likelihood(log_hazard, event_indicator, event_time):
    unique_times, counts = torch.unique(event_time[event_indicator == 1], return_counts=True)
    print(unique_times, counts)
    partial_likelihood = 0
    for t, d in zip(unique_times, counts):
        risk_set = torch.sum(torch.exp(log_hazard[event_time >= t]))
        partial_likelihood += torch.sum(log_hazard[(event_time == t) & (event_indicator == 1)]) - d * torch.log(risk_set)
        print(t, d, risk_set)
    return partial_likelihood

def efron_partial_likelihood(log_hazard, event_indicator, event_time):
    unique_times, counts = torch.unique(event_time[event_indicator == 1], return_counts=True)
    partial_likelihood = 0
    for t, d in zip(unique_times, counts):
        risk_set = torch.sum(torch.exp(log_hazard[event_time >= t]))
        tied_hazard_sum = torch.sum(torch.exp(log_hazard[(event_time == t) & (event_indicator == 1)]))
        for k in range(d):
            partial_likelihood += (torch.sum(log_hazard[(event_time == t) & (event_indicator == 1)]) - torch.log(risk_set - k * tied_hazard_sum / d))
    return partial_likelihood

# Example usage
log_hazard = torch.tensor([0.5, 1.0, 1.0, 1.5, 2.0])
event_indicator = torch.tensor([1, 1, 0, 1, 1])
event_time = torch.tensor([1, 2, 2, 2, 3])

log_hazard = torch.tensor([0.5, 1.0, 1.5, 2.0])
event_indicator = torch.tensor([1, 1, 1, 1])
event_time = torch.tensor([1, 2, 2, 3])

reduction = 'mean' # or 'sum', depending on your needs
torchsurv_ll_breslow = tscox.neg_partial_log_likelihood(log_hazard, event_indicator, event_time, ties_method='breslow', reduction = reduction)
torchsurv_ll_efron = tscox.neg_partial_log_likelihood(log_hazard, event_indicator, event_time, ties_method='efron', reduction = reduction)
partial_ll_naive = naive_partial_likelihood(log_hazard, event_indicator, event_time)
partial_ll_breslow = breslow_partial_likelihood(log_hazard, event_indicator, event_time)
partial_ll_efron = efron_partial_likelihood(log_hazard, event_indicator, event_time)

print("---")
print("TorchSurv Breslow Partial Likelihood:", torchsurv_ll_breslow.item())
print("TorchSurv Efron Partial Likelihood:  ", torchsurv_ll_efron.item())
print("---")
print("Naive Partial Likelihood:  ", partial_ll_naive.item())
print("Breslow Partial Likelihood:", partial_ll_breslow.item())
print("Efron Partial Likelihood:  ", partial_ll_efron.item())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 31
#      28     return partial_likelihood
#      30 # Example usage
# ---> 31 log_hazard = torch.tensor([0.5, 1.0, 1.0, 1.5, 2.0])
#      32 event_indicator = torch.tensor([1, 1, 0, 1, 1])
#      33 event_time = torch.tensor([1, 2, 2, 2, 3])
#
# NameError: name 'torch' is not defined

# %% [markdown]
# ---
#
# # Survival Analysis with TorchSurv and Artificial Data
#
# This notebook demonstrates:
# 1. Generating artificial survival data
# 2. Training a TorchSurv LogHazard model
# 3. Evaluating and visualizing the results using stratification plots

# %%
# Set environment variable to handle OpenMP runtime conflict
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'

# Also set this for the current session
if os.name == 'nt':  # Windows
    try:
        import ctypes
        ctypes.CDLL('mkl_rt.dll')
    except:
        pass

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from lifelines import KaplanMeierFitter

# Import required libraries
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import torchsurv.loss.cox as tscox

# Import ukko survival functions
from ukko.survival import generate_survival_data_LL, plot_KM

# %%
import importlib
import ukko.survival
importlib.reload(ukko.survival)

def generate_data(n_samples=1000, n_features=3, n_informative=1, 
                 shape=5, scale=10.0, censoring=0.3, random_seed=42, 
                 nonlinear = True):
    """Generate synthetic survival data with log-logistic distribution."""
    np.random.seed(random_seed)
    
    survival_data, true_coefficients = ukko.survival.generate_survival_data_LL(
        n_samples, n_features, n_informative,
        shape, scale, censoring,
        nonlinear = nonlinear
    )
    feature_cols = [col for col in survival_data.columns if col.startswith('feature_')]
    
    return survival_data, true_coefficients, feature_cols

def prepare_data_for_pytorch(survival_data, feature_cols):
    """Prepare survival data for PyTorch."""
    # Prepare data for PyTorch
    X = torch.FloatTensor(survival_data[feature_cols].values)
    times = torch.FloatTensor(survival_data['observed_time'].values)
    events = torch.FloatTensor(survival_data['event_observed'].values)
    # Create data loader
    dataset = TensorDataset(X, times, events)
    batch_size = X.shape[0]  # Use the entire dataset as one batch
    train_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
    return train_loader


# Generate linear data:
survival_data_lin, true_coefficients_lin, feature_cols_lin = \
  generate_data(nonlinear=False)
train_loader_lin = prepare_data_for_pytorch(survival_data_lin, feature_cols_lin)

# Generate nonlinear data:
survival_data_nonlin, true_coefficients_nonlin, feature_cols_nonlin = \
  generate_data(nonlinear=True)
train_loader_nonlin = prepare_data_for_pytorch(survival_data_nonlin, feature_cols_nonlin)
plt.title("Generated Nonlinear Survival Data")

# Plot initial KM curve for the entire dataset
plot_KM(survival_data_lin)
plot_KM(survival_data_nonlin)

print("\nData shape:", survival_data_nonlin.shape)
print("Number of events:", survival_data_nonlin['event_observed'].sum())
print("Censoring rate:", 1 - survival_data_nonlin['event_observed'].mean())
# Out:
# Data shape: (1000, 6)
# Number of events: 700
# Censoring rate: 0.30000000000000004

# %% [markdown]
# ### Helper functions

# %%
def stratify_and_plot(survival_data, risk_scores, n_groups=4, model_name=''):
    """Stratify patients into multiple risk groups and plot KM curves."""
    survival_data = survival_data.copy()
    survival_data['predicted_risk'] = risk_scores
    
    # Calculate quantile cutoffs
    quantiles = np.linspace(0, 1, n_groups + 1)
    cutoffs = np.quantile(survival_data['predicted_risk'], quantiles)
    
    # Plot KM curves
    plt.figure(figsize=(12, 8))
    
    # Create color map for groups
    try:
        colors = plt.cm.managua(np.linspace(0, 1, n_groups))
    except:
        colors = plt.cm.viridis(np.linspace(0, 1, n_groups))
    
    for i in range(n_groups):
        if i == 0:
            mask = survival_data['predicted_risk'] <= cutoffs[1]
            group_label = f'Lowest Risk (Q1)'
        elif i == n_groups - 1:
            mask = survival_data['predicted_risk'] > cutoffs[-2]
            group_label = f'Highest Risk (Q{n_groups})'
        else:
            mask = (survival_data['predicted_risk'] > cutoffs[i]) & \
                   (survival_data['predicted_risk'] <= cutoffs[i+1])
            group_label = f'Q{i+1}'
        
        group = survival_data[mask]
        
        kmf = KaplanMeierFitter()
        kmf.fit(durations=group['observed_time'],
                event_observed=group['event_observed'],
                label=group_label)
        kmf.plot_survival_function(show_censors=True, ci_show=False, color=colors[i])
        
        print(f"{group_label} size: {len(group)}")
    
    plt.title(f'Kaplan-Meier Survival Curves by Risk Group ({model_name})')
    plt.xlabel('Time')
    plt.ylabel('Survival Probability')
    plt.grid(True)
    plt.legend()
    plt.show()
    
    return cutoffs

def plot_training_loss(result):
  model, history, best_loss = result
  # Plot training loss
  plt.figure(figsize=(10, 6))
  plt.plot(history['train_loss'])
  plt.axhline(y=best_loss, color='r', linestyle='--', label='Best Loss')
  plt.title('Training Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend()
  plt.show()

# %% [markdown]
# ## Define models

# %%
# Define the LogHazard model
class LogHazardModel(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 32),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(16, 1)
        )
    
    def forward(self, x):
        return self.network(x)

# Define ukko loghazard model for 1-timepoint data using dual attention mechanism
from ukko.core import DualAttentionRegressor1
class UkkoLogHazardModel(nn.Module):
    """A PyTorch model for survival analysis using a dual attention mechanism."""
    def __init__(self, n_features):
        super().__init__()
        self.attention_net = DualAttentionRegressor1(
            n_features=n_features,
            time_steps=1,  # Since we're using instantaneous inputs
            d_model=64,
            n_heads=4,
            dropout=0.1,
            n_modules=3
        )
    
    def forward(self, x):
        # Add time dimension expected by DualAttentionRegressor
        x = x.unsqueeze(2)  # [batch_size, n_features, 1]
        
        # Get predictions from attention network
        predictions, feat_weights, time_weights = self.attention_net(x)
        
        return predictions, feat_weights, time_weights

# %% [markdown]
# ## Compare linear and ukko loghazard models

# %% [markdown]
# ### Linear data

# %%
n_epochs = 500

import importlib
import ukko.core
from ukko.core import train_model_simple
#from ukko.core import UkkoLogHazardModel, train_model_simple
importlib.reload(ukko.core)

# Linear Model:
model_lin = LogHazardModel(len(feature_cols_lin))
optimizer_lin = torch.optim.Adam(model_lin.parameters(), lr=0.001)
reduction = 'mean'

# Ukko LogHazard Model:
model = UkkoLogHazardModel(len(feature_cols_lin))
#model = ukko.core.UkkoLogHazardModel(len(feature_cols))
optimizer = torch.optim.Adam(model.parameters(), lr=0.0005)
reduction = 'mean'

# Train the linear model
print("Training Linear Model...")
#model, history, best_loss = train_model_simple(
result_lin = train_model_simple(
    model_lin, 
    train_loader_lin, 
    optimizer_lin,
    n_epochs=n_epochs,
    device='cuda',
    reduction=reduction
)

print("Training Ukko LogHazard Model...")
# Train the linear model
result_ukko = train_model_simple(
    model, 
    train_loader_lin, 
    optimizer,
    n_epochs=n_epochs,
    device='cuda',
    reduction=reduction
)
print(" ")

plot_training_loss(result_lin)
plot_training_loss(result_ukko)
# Out:
# Training Linear Model...
# /users/ericfey1/.local/lib/python3.11/site-packages/torchsurv/loss/cox.py:138: UserWarning: Ties in event time detected; using efron's method to handle ties.
#   warnings.warn(
# Epoch 10/500, Loss: 5.9050, Best Loss: 5.9050
# Epoch 20/500, Loss: 5.8627, Best Loss: 5.8627
# Epoch 30/500, Loss: 5.8230, Best Loss: 5.8230
# Epoch 40/500, Loss: 5.7807, Best Loss: 5.7807
# Epoch 50/500, Loss: 5.7401, Best Loss: 5.7401
# Epoch 60/500, Loss: 5.6973, Best Loss: 5.6973
# Epoch 70/500, Loss: 5.6604, Best Loss: 5.6604
# Epoch 80/500, Loss: 5.6389, Best Loss: 5.6341
# Epoch 90/500, Loss: 5.6192, Best Loss: 5.6136
# Epoch 100/500, Loss: 5.6306, Best Loss: 5.5986
# Epoch 110/500, Loss: 5.5961, Best Loss: 5.5961
# Epoch 120/500, Loss: 5.6083, Best Loss: 5.5961
# Epoch 130/500, Loss: 5.5954, Best Loss: 5.5909
# Epoch 140/500, Loss: 5.6097, Best Loss: 5.5858
# Epoch 150/500, Loss: 5.6087, Best Loss: 5.5858
# Epoch 160/500, Loss: 5.5898, Best Loss: 5.5858
# Epoch 170/500, Loss: 5.6152, Best Loss: 5.5828
# Epoch 180/500, Loss: 5.6126, Best Loss: 5.5787
# Epoch 190/500, Loss: 5.5981, Best Loss: 5.5783
# Epoch 200/500, Loss: 5.5710, Best Loss: 5.5710
# Epoch 210/500, Loss: 5.5831, Best Loss: 5.5710
# Epoch 220/500, Loss: 5.5603, Best Loss: 5.5603
# Epoch 230/500, Loss: 5.5773, Best Loss: 5.5603
# Epoch 240/500, Loss: 5.5704, Best Loss: 5.5603
# Epoch 250/500, Loss: 5.5910, Best Loss: 5.5603
# Epoch 260/500, Loss: 5.5813, Best Loss: 5.5603
# Epoch 270/500, Loss: 5.5891, Best Loss: 5.5603
# Epoch 280/500, Loss: 5.5669, Best Loss: 5.5603
# Epoch 290/500, Loss: 5.5913, Best Loss: 5.5603
# Epoch 300/500, Loss: 5.5603, Best Loss: 5.5547
# Epoch 310/500, Loss: 5.5777, Best Loss: 5.5547
# Epoch 320/500, Loss: 5.5742, Best Loss: 5.5547
# Epoch 330/500, Loss: 5.5870, Best Loss: 5.5547
# Epoch 340/500, Loss: 5.5642, Best Loss: 5.5547
# Epoch 350/500, Loss: 5.5875, Best Loss: 5.5547
# Epoch 360/500, Loss: 5.5710, Best Loss: 5.5547
# Epoch 370/500, Loss: 5.5822, Best Loss: 5.5547
# Epoch 380/500, Loss: 5.5580, Best Loss: 5.5547
# Epoch 390/500, Loss: 5.5875, Best Loss: 5.5547
# Epoch 400/500, Loss: 5.5844, Best Loss: 5.5547
# Epoch 410/500, Loss: 5.5628, Best Loss: 5.5547
# Epoch 420/500, Loss: 5.5753, Best Loss: 5.5547
# Epoch 430/500, Loss: 5.5771, Best Loss: 5.5547
# Epoch 440/500, Loss: 5.5553, Best Loss: 5.5547
# Epoch 450/500, Loss: 5.5823, Best Loss: 5.5547
# Epoch 460/500, Loss: 5.5657, Best Loss: 5.5547
# Epoch 470/500, Loss: 5.5705, Best Loss: 5.5547
# Epoch 480/500, Loss: 5.5785, Best Loss: 5.5547
# Epoch 490/500, Loss: 5.5750, Best Loss: 5.5547
# Epoch 500/500, Loss: 5.5840, Best Loss: 5.5547
# Training Ukko LogHazard Model...
# Epoch 10/500, Loss: 5.8639, Best Loss: 5.8516
# Epoch 20/500, Loss: 5.8491, Best Loss: 5.8491
# Epoch 30/500, Loss: 5.8478, Best Loss: 5.8400
# Epoch 40/500, Loss: 5.8391, Best Loss: 5.8361
# Epoch 50/500, Loss: 5.8409, Best Loss: 5.8303
# Epoch 60/500, Loss: 5.8364, Best Loss: 5.8303
# Epoch 70/500, Loss: 5.8332, Best Loss: 5.8230
# Epoch 80/500, Loss: 5.8265, Best Loss: 5.8190
# Epoch 90/500, Loss: 5.8238, Best Loss: 5.8176
# Epoch 100/500, Loss: 5.8150, Best Loss: 5.8083
# Epoch 110/500, Loss: 5.8072, Best Loss: 5.8072
# Epoch 120/500, Loss: 5.8010, Best Loss: 5.7989
# Epoch 130/500, Loss: 5.7909, Best Loss: 5.7865
# Epoch 140/500, Loss: 5.7849, Best Loss: 5.7723
# Epoch 150/500, Loss: 5.7688, Best Loss: 5.7608
# Epoch 160/500, Loss: 5.7562, Best Loss: 5.7466
# Epoch 170/500, Loss: 5.7516, Best Loss: 5.7439
# Epoch 180/500, Loss: 5.7448, Best Loss: 5.7266
# Epoch 190/500, Loss: 5.7255, Best Loss: 5.7154
# Epoch 200/500, Loss: 5.7052, Best Loss: 5.6965
# Epoch 210/500, Loss: 5.6856, Best Loss: 5.6843
# Epoch 220/500, Loss: 5.6617, Best Loss: 5.6617
# Epoch 230/500, Loss: 5.6504, Best Loss: 5.6301
# Epoch 240/500, Loss: 5.6035, Best Loss: 5.6035
# Epoch 250/500, Loss: 5.5932, Best Loss: 5.5801
# Epoch 260/500, Loss: 5.5918, Best Loss: 5.5613
# Epoch 270/500, Loss: 5.5407, Best Loss: 5.5385
# Epoch 280/500, Loss: 5.5247, Best Loss: 5.5247
# Epoch 290/500, Loss: 5.5166, Best Loss: 5.5016
# Epoch 300/500, Loss: 5.4797, Best Loss: 5.4797
# Epoch 310/500, Loss: 5.4711, Best Loss: 5.4695
# Epoch 320/500, Loss: 5.4797, Best Loss: 5.4611
# Epoch 330/500, Loss: 5.4648, Best Loss: 5.4545
# Epoch 340/500, Loss: 5.4458, Best Loss: 5.4458
# Epoch 350/500, Loss: 5.4507, Best Loss: 5.4388
# Epoch 360/500, Loss: 5.4466, Best Loss: 5.4327
# Epoch 370/500, Loss: 5.4775, Best Loss: 5.4262
# Epoch 380/500, Loss: 5.4635, Best Loss: 5.4262
# Epoch 390/500, Loss: 5.4533, Best Loss: 5.4262
# Epoch 400/500, Loss: 5.4523, Best Loss: 5.4262
# Epoch 410/500, Loss: 5.4566, Best Loss: 5.4262
# Epoch 420/500, Loss: 5.4242, Best Loss: 5.4242
# Epoch 430/500, Loss: 5.4486, Best Loss: 5.4242
# Epoch 440/500, Loss: 5.4395, Best Loss: 5.4191
# Epoch 450/500, Loss: 5.4426, Best Loss: 5.4126
# Epoch 460/500, Loss: 5.4303, Best Loss: 5.4123
# Epoch 470/500, Loss: 5.4277, Best Loss: 5.4044
# Epoch 480/500, Loss: 5.4114, Best Loss: 5.4044
# Epoch 490/500, Loss: 5.4248, Best Loss: 5.4003
# Epoch 500/500, Loss: 5.4326, Best Loss: 5.4003

# %%
# Linear Model performance evaluation:
X =  train_loader_lin.dataset.tensors[0].cpu()

# Generate risk scores using the trained linear model
model_lin.eval().to('cpu')
with torch.no_grad():
    risk_scores_lin = model_lin(X).numpy().flatten()
# Create stratification plot
cutoffs_lin = stratify_and_plot(survival_data_lin, risk_scores_lin, n_groups=5,
                            model_name='Linear Model')

# Ukko Model performance evaluation:
# Generate risk scores using the trained ukko model
model.eval().cpu()
with torch.no_grad():
    risk_scores, feat_weights, time_weights = model(X)
    risk_scores = risk_scores.numpy()
# Create stratification plot
cutoffs = stratify_and_plot(survival_data_lin, risk_scores, n_groups=5, 
                            model_name='Ukko LogHazard Model')
# Out:
# Lowest Risk (Q1) size: 200
# Q2 size: 200
# Q3 size: 200
# Q4 size: 200
# Highest Risk (Q5) size: 200
# Lowest Risk (Q1) size: 200
# Q2 size: 200
# Q3 size: 200
# Q4 size: 200
# Highest Risk (Q5) size: 200

# %% [markdown]
# ### Non-linear data

# %%
importlib.reload(ukko.core)
# Out:
# <module 'ukko.core' from '/users/ericfey1/github/ukko/src/ukko/core.py'>

# %%
n_epochs = 4000

# Linear Model:
model_lin = LogHazardModel(len(feature_cols_nonlin))
optimizer_lin = torch.optim.Adam(model_lin.parameters(), lr=0.001)
reduction = 'mean'

# Ukko LogHazard Model:
model = UkkoLogHazardModel(len(feature_cols_nonlin))
#model = ukko.core.UkkoLogHazardModel(len(feature_cols))
optimizer = torch.optim.Adam(model.parameters(), lr=0.0002)
reduction = 'mean'

# Train the linear model
print("Training Linear Model...")
#model, history, best_loss = train_model_simple(
result_lin = train_model_simple(
    model_lin, 
    train_loader_nonlin, 
    optimizer_lin,
    n_epochs=n_epochs // 10,
    device='cuda',
    reduction=reduction
)

print("Training Ukko LogHazard Model...")
# Train the ukko model
result_ukko = train_model_simple(
    model, 
    train_loader_nonlin, 
    optimizer,
    n_epochs=n_epochs,
    device='gpu',
    reduction=reduction
)
print(" ")

plot_training_loss(result_lin)
plot_training_loss(result_ukko)

# Linear Model performance evaluation:
X =  train_loader_nonlin.dataset.tensors[0].cpu()

# Generate risk scores using the trained model
model_lin.eval().to('cpu')
with torch.no_grad():
    risk_scores_lin = model_lin(X).numpy().flatten()
# Create stratification plot
cutoffs_lin = stratify_and_plot(survival_data_nonlin, risk_scores_lin, n_groups=5,
                            model_name='Linear Model')

# Ukko Model performance evaluation:
# Generate risk scores using the trained model
model.eval().to('cpu')
with torch.no_grad():
    risk_scores, feat_weights, time_weights = model(X)
    risk_scores = risk_scores.numpy()

# Create stratification plot
cutoffs = stratify_and_plot(survival_data_nonlin, risk_scores, n_groups=5, 
                            model_name='Ukko LogHazard Model')
# Out:
# Training Linear Model...
# Epoch 10/400, Loss: 5.9274, Best Loss: 5.9274
# Epoch 20/400, Loss: 5.9229, Best Loss: 5.9229
# Epoch 30/400, Loss: 5.9227, Best Loss: 5.9171
# Epoch 40/400, Loss: 5.9180, Best Loss: 5.9171
# Epoch 50/400, Loss: 5.9182, Best Loss: 5.9130
# Epoch 60/400, Loss: 5.9132, Best Loss: 5.9128
# Epoch 70/400, Loss: 5.9156, Best Loss: 5.9096
# Epoch 80/400, Loss: 5.9142, Best Loss: 5.9076
# Epoch 90/400, Loss: 5.9112, Best Loss: 5.9076
# Epoch 100/400, Loss: 5.9086, Best Loss: 5.9065
# Epoch 110/400, Loss: 5.9130, Best Loss: 5.9065
# Epoch 120/400, Loss: 5.9068, Best Loss: 5.9051
# Epoch 130/400, Loss: 5.9087, Best Loss: 5.9041
# Epoch 140/400, Loss: 5.9096, Best Loss: 5.9041
# Epoch 150/400, Loss: 5.8993, Best Loss: 5.8993
# Epoch 160/400, Loss: 5.9134, Best Loss: 5.8993
# Epoch 170/400, Loss: 5.9047, Best Loss: 5.8993
# Epoch 180/400, Loss: 5.9008, Best Loss: 5.8993
# Epoch 190/400, Loss: 5.9063, Best Loss: 5.8993
# Epoch 200/400, Loss: 5.8991, Best Loss: 5.8967
# Epoch 210/400, Loss: 5.9048, Best Loss: 5.8963
# Epoch 220/400, Loss: 5.8983, Best Loss: 5.8963
# Epoch 230/400, Loss: 5.9040, Best Loss: 5.8949
# Epoch 240/400, Loss: 5.8995, Best Loss: 5.8929
# Epoch 250/400, Loss: 5.8913, Best Loss: 5.8913
# Epoch 260/400, Loss: 5.8989, Best Loss: 5.8913
# Epoch 270/400, Loss: 5.9049, Best Loss: 5.8913
# Epoch 280/400, Loss: 5.8902, Best Loss: 5.8902
# Epoch 290/400, Loss: 5.8963, Best Loss: 5.8902
# Epoch 300/400, Loss: 5.8948, Best Loss: 5.8891
# Epoch 310/400, Loss: 5.8865, Best Loss: 5.8865
# Epoch 320/400, Loss: 5.8984, Best Loss: 5.8865
# Epoch 330/400, Loss: 5.8990, Best Loss: 5.8865
# Epoch 340/400, Loss: 5.8962, Best Loss: 5.8865
# Epoch 350/400, Loss: 5.8910, Best Loss: 5.8865
# Epoch 360/400, Loss: 5.8977, Best Loss: 5.8865
# Epoch 370/400, Loss: 5.8880, Best Loss: 5.8865
# Epoch 380/400, Loss: 5.9013, Best Loss: 5.8865
# Epoch 390/400, Loss: 5.8923, Best Loss: 5.8865
# Epoch 400/400, Loss: 5.8971, Best Loss: 5.8839
# Training Ukko LogHazard Model...
# Epoch 10/4000, Loss: 5.9252, Best Loss: 5.9251
# Epoch 20/4000, Loss: 5.9242, Best Loss: 5.9226
# Epoch 30/4000, Loss: 5.9217, Best Loss: 5.9217
# Epoch 40/4000, Loss: 5.9208, Best Loss: 5.9149
# Epoch 50/4000, Loss: 5.9074, Best Loss: 5.9074
# Epoch 60/4000, Loss: 5.9069, Best Loss: 5.9061
# Epoch 70/4000, Loss: 5.9035, Best Loss: 5.8971
# Epoch 80/4000, Loss: 5.9011, Best Loss: 5.8970
# Epoch 90/4000, Loss: 5.8997, Best Loss: 5.8961
# Epoch 100/4000, Loss: 5.9000, Best Loss: 5.8942
# Epoch 110/4000, Loss: 5.8995, Best Loss: 5.8893
# Epoch 120/4000, Loss: 5.8982, Best Loss: 5.8881
# Epoch 130/4000, Loss: 5.8944, Best Loss: 5.8881
# Epoch 140/4000, Loss: 5.8948, Best Loss: 5.8870
# Epoch 150/4000, Loss: 5.8888, Best Loss: 5.8870
# Epoch 160/4000, Loss: 5.8943, Best Loss: 5.8870
# Epoch 170/4000, Loss: 5.8914, Best Loss: 5.8846
# Epoch 180/4000, Loss: 5.8911, Best Loss: 5.8846
# Epoch 190/4000, Loss: 5.8875, Best Loss: 5.8846
# Epoch 200/4000, Loss: 5.8912, Best Loss: 5.8830
# Epoch 210/4000, Loss: 5.8889, Best Loss: 5.8830
# Epoch 220/4000, Loss: 5.8885, Best Loss: 5.8830
# Epoch 230/4000, Loss: 5.8851, Best Loss: 5.8830
# Epoch 240/4000, Loss: 5.8847, Best Loss: 5.8801
# Epoch 250/4000, Loss: 5.8747, Best Loss: 5.8740
# Epoch 260/4000, Loss: 5.8806, Best Loss: 5.8717
# Epoch 270/4000, Loss: 5.8767, Best Loss: 5.8717
# Epoch 280/4000, Loss: 5.8744, Best Loss: 5.8670
# Epoch 290/4000, Loss: 5.8813, Best Loss: 5.8670
# Epoch 300/4000, Loss: 5.8746, Best Loss: 5.8670
# Epoch 310/4000, Loss: 5.8755, Best Loss: 5.8629
# Epoch 320/4000, Loss: 5.8742, Best Loss: 5.8598
# Epoch 330/4000, Loss: 5.8708, Best Loss: 5.8596
# Epoch 340/4000, Loss: 5.8623, Best Loss: 5.8584
# Epoch 350/4000, Loss: 5.8670, Best Loss: 5.8550
# Epoch 360/4000, Loss: 5.8602, Best Loss: 5.8529
# Epoch 370/4000, Loss: 5.8622, Best Loss: 5.8529
# Epoch 380/4000, Loss: 5.8627, Best Loss: 5.8529
# Epoch 390/4000, Loss: 5.8688, Best Loss: 5.8529
# Epoch 400/4000, Loss: 5.8622, Best Loss: 5.8529
# Epoch 410/4000, Loss: 5.8559, Best Loss: 5.8485
# Epoch 420/4000, Loss: 5.8625, Best Loss: 5.8485
# Epoch 430/4000, Loss: 5.8548, Best Loss: 5.8485
# Epoch 440/4000, Loss: 5.8523, Best Loss: 5.8485
# Epoch 450/4000, Loss: 5.8520, Best Loss: 5.8485
# Epoch 460/4000, Loss: 5.8607, Best Loss: 5.8470
# Epoch 470/4000, Loss: 5.8450, Best Loss: 5.8450
# Epoch 480/4000, Loss: 5.8479, Best Loss: 5.8398
# Epoch 490/4000, Loss: 5.8451, Best Loss: 5.8350
# Epoch 500/4000, Loss: 5.8494, Best Loss: 5.8350
# Epoch 510/4000, Loss: 5.8477, Best Loss: 5.8350
# Epoch 520/4000, Loss: 5.8383, Best Loss: 5.8350
# Epoch 530/4000, Loss: 5.8407, Best Loss: 5.8313
# Epoch 540/4000, Loss: 5.8472, Best Loss: 5.8300
# Epoch 550/4000, Loss: 5.8389, Best Loss: 5.8300
# Epoch 560/4000, Loss: 5.8360, Best Loss: 5.8300
# Epoch 570/4000, Loss: 5.8369, Best Loss: 5.8274
# Epoch 580/4000, Loss: 5.8323, Best Loss: 5.8274
# Epoch 590/4000, Loss: 5.8328, Best Loss: 5.8255
# Epoch 600/4000, Loss: 5.8253, Best Loss: 5.8136
# Epoch 610/4000, Loss: 5.8325, Best Loss: 5.8136
# Epoch 620/4000, Loss: 5.8323, Best Loss: 5.8136
# Epoch 630/4000, Loss: 5.8160, Best Loss: 5.8136
# Epoch 640/4000, Loss: 5.8241, Best Loss: 5.8103
# Epoch 650/4000, Loss: 5.8295, Best Loss: 5.8085
# Epoch 660/4000, Loss: 5.8184, Best Loss: 5.8076
# Epoch 670/4000, Loss: 5.8096, Best Loss: 5.8055
# Epoch 680/4000, Loss: 5.8106, Best Loss: 5.8045
# Epoch 690/4000, Loss: 5.8053, Best Loss: 5.8013
# Epoch 700/4000, Loss: 5.8202, Best Loss: 5.8013
# Epoch 710/4000, Loss: 5.8047, Best Loss: 5.8010
# Epoch 720/4000, Loss: 5.8003, Best Loss: 5.8003
# Epoch 730/4000, Loss: 5.8076, Best Loss: 5.7951
# Epoch 740/4000, Loss: 5.7924, Best Loss: 5.7924
# Epoch 750/4000, Loss: 5.7943, Best Loss: 5.7899
# Epoch 760/4000, Loss: 5.7983, Best Loss: 5.7808
# Epoch 770/4000, Loss: 5.8135, Best Loss: 5.7784
# Epoch 780/4000, Loss: 5.7932, Best Loss: 5.7784
# Epoch 790/4000, Loss: 5.8125, Best Loss: 5.7784
# Epoch 800/4000, Loss: 5.7926, Best Loss: 5.7784
# Epoch 810/4000, Loss: 5.7864, Best Loss: 5.7744
# Epoch 820/4000, Loss: 5.7780, Best Loss: 5.7719
# Epoch 830/4000, Loss: 5.7786, Best Loss: 5.7676
# Epoch 840/4000, Loss: 5.7780, Best Loss: 5.7676
# Epoch 850/4000, Loss: 5.7897, Best Loss: 5.7668
# Epoch 860/4000, Loss: 5.7694, Best Loss: 5.7638
# Epoch 870/4000, Loss: 5.7836, Best Loss: 5.7638
# Epoch 880/4000, Loss: 5.7713, Best Loss: 5.7543
# Epoch 890/4000, Loss: 5.7594, Best Loss: 5.7517
# Epoch 900/4000, Loss: 5.7600, Best Loss: 5.7505
# Epoch 910/4000, Loss: 5.7655, Best Loss: 5.7490
# Epoch 920/4000, Loss: 5.7734, Best Loss: 5.7490
# Epoch 930/4000, Loss: 5.7518, Best Loss: 5.7490
# Epoch 940/4000, Loss: 5.7613, Best Loss: 5.7490
# Epoch 950/4000, Loss: 5.7638, Best Loss: 5.7419
# Epoch 960/4000, Loss: 5.7644, Best Loss: 5.7419
# Epoch 970/4000, Loss: 5.7648, Best Loss: 5.7337
# Epoch 980/4000, Loss: 5.7599, Best Loss: 5.7337
# Epoch 990/4000, Loss: 5.7816, Best Loss: 5.7337
# Epoch 1000/4000, Loss: 5.7668, Best Loss: 5.7337
# Epoch 1010/4000, Loss: 5.7508, Best Loss: 5.7308
# Epoch 1020/4000, Loss: 5.7547, Best Loss: 5.7277
# Epoch 1030/4000, Loss: 5.7451, Best Loss: 5.7277
# Epoch 1040/4000, Loss: 5.7430, Best Loss: 5.7186
# Epoch 1050/4000, Loss: 5.7438, Best Loss: 5.7186
# Epoch 1060/4000, Loss: 5.7330, Best Loss: 5.7123
# Epoch 1070/4000, Loss: 5.7304, Best Loss: 5.7094
# Epoch 1080/4000, Loss: 5.7250, Best Loss: 5.7094
# Epoch 1090/4000, Loss: 5.7204, Best Loss: 5.7094
# Epoch 1100/4000, Loss: 5.7294, Best Loss: 5.7094
# Epoch 1110/4000, Loss: 5.7205, Best Loss: 5.7059
# Epoch 1120/4000, Loss: 5.7270, Best Loss: 5.7059
# Epoch 1130/4000, Loss: 5.7208, Best Loss: 5.7059
# Epoch 1140/4000, Loss: 5.7058, Best Loss: 5.6993
# Epoch 1150/4000, Loss: 5.7221, Best Loss: 5.6993
# Epoch 1160/4000, Loss: 5.7001, Best Loss: 5.6928
# Epoch 1170/4000, Loss: 5.7194, Best Loss: 5.6928
# Epoch 1180/4000, Loss: 5.7130, Best Loss: 5.6928
# Epoch 1190/4000, Loss: 5.7260, Best Loss: 5.6928
# Epoch 1200/4000, Loss: 5.6820, Best Loss: 5.6794
# Epoch 1210/4000, Loss: 5.6980, Best Loss: 5.6794
# Epoch 1220/4000, Loss: 5.6993, Best Loss: 5.6794
# Epoch 1230/4000, Loss: 5.7026, Best Loss: 5.6794
# Epoch 1240/4000, Loss: 5.7070, Best Loss: 5.6733
# Epoch 1250/4000, Loss: 5.6853, Best Loss: 5.6674
# Epoch 1260/4000, Loss: 5.6764, Best Loss: 5.6674
# Epoch 1270/4000, Loss: 5.6819, Best Loss: 5.6674
# Epoch 1280/4000, Loss: 5.6837, Best Loss: 5.6674
# Epoch 1290/4000, Loss: 5.6780, Best Loss: 5.6664
# Epoch 1300/4000, Loss: 5.6669, Best Loss: 5.6664
# Epoch 1310/4000, Loss: 5.6730, Best Loss: 5.6652
# Epoch 1320/4000, Loss: 5.7023, Best Loss: 5.6583
# Epoch 1330/4000, Loss: 5.7023, Best Loss: 5.6583
# Epoch 1340/4000, Loss: 5.6551, Best Loss: 5.6551
# Epoch 1350/4000, Loss: 5.6683, Best Loss: 5.6551
# Epoch 1360/4000, Loss: 5.6727, Best Loss: 5.6458
# Epoch 1370/4000, Loss: 5.6571, Best Loss: 5.6458
# Epoch 1380/4000, Loss: 5.6538, Best Loss: 5.6458
# Epoch 1390/4000, Loss: 5.6705, Best Loss: 5.6458
# Epoch 1400/4000, Loss: 5.6782, Best Loss: 5.6415
# Epoch 1410/4000, Loss: 5.6600, Best Loss: 5.6415
# Epoch 1420/4000, Loss: 5.6544, Best Loss: 5.6415
# Epoch 1430/4000, Loss: 5.6794, Best Loss: 5.6376
# Epoch 1440/4000, Loss: 5.6476, Best Loss: 5.6376
# Epoch 1450/4000, Loss: 5.6464, Best Loss: 5.6343
# Epoch 1460/4000, Loss: 5.6541, Best Loss: 5.6172
# Epoch 1470/4000, Loss: 5.6642, Best Loss: 5.6172
# Epoch 1480/4000, Loss: 5.6205, Best Loss: 5.6172
# Epoch 1490/4000, Loss: 5.6488, Best Loss: 5.6172
# Epoch 1500/4000, Loss: 5.6342, Best Loss: 5.6172
# Epoch 1510/4000, Loss: 5.6411, Best Loss: 5.6172
# Epoch 1520/4000, Loss: 5.6367, Best Loss: 5.6153
# Epoch 1530/4000, Loss: 5.6392, Best Loss: 5.6153
# Epoch 1540/4000, Loss: 5.6229, Best Loss: 5.6069
# Epoch 1550/4000, Loss: 5.6662, Best Loss: 5.5916
# Epoch 1560/4000, Loss: 5.6694, Best Loss: 5.5916
# Epoch 1570/4000, Loss: 5.6061, Best Loss: 5.5916
# Epoch 1580/4000, Loss: 5.6334, Best Loss: 5.5916
# Epoch 1590/4000, Loss: 5.6151, Best Loss: 5.5916
# Epoch 1600/4000, Loss: 5.6120, Best Loss: 5.5911
# Epoch 1610/4000, Loss: 5.6316, Best Loss: 5.5911
# Epoch 1620/4000, Loss: 5.5972, Best Loss: 5.5911
# Epoch 1630/4000, Loss: 5.5975, Best Loss: 5.5911
# Epoch 1640/4000, Loss: 5.6134, Best Loss: 5.5906
# Epoch 1650/4000, Loss: 5.6066, Best Loss: 5.5906
# Epoch 1660/4000, Loss: 5.6129, Best Loss: 5.5906
# Epoch 1670/4000, Loss: 5.6134, Best Loss: 5.5778
# Epoch 1680/4000, Loss: 5.5890, Best Loss: 5.5778
# Epoch 1690/4000, Loss: 5.6143, Best Loss: 5.5778
# Epoch 1700/4000, Loss: 5.5838, Best Loss: 5.5778
# Epoch 1710/4000, Loss: 5.6208, Best Loss: 5.5755
# Epoch 1720/4000, Loss: 5.5701, Best Loss: 5.5701
# Epoch 1730/4000, Loss: 5.6010, Best Loss: 5.5701
# Epoch 1740/4000, Loss: 5.6228, Best Loss: 5.5588
# Epoch 1750/4000, Loss: 5.6040, Best Loss: 5.5588
# Epoch 1760/4000, Loss: 5.5944, Best Loss: 5.5588
# Epoch 1770/4000, Loss: 5.6016, Best Loss: 5.5588
# Epoch 1780/4000, Loss: 5.5883, Best Loss: 5.5588
# Epoch 1790/4000, Loss: 5.5809, Best Loss: 5.5588
# Epoch 1800/4000, Loss: 5.6096, Best Loss: 5.5534
# Epoch 1810/4000, Loss: 5.5805, Best Loss: 5.5534
# Epoch 1820/4000, Loss: 5.5991, Best Loss: 5.5534
# Epoch 1830/4000, Loss: 5.5622, Best Loss: 5.5503
# Epoch 1840/4000, Loss: 5.5636, Best Loss: 5.5424
# Epoch 1850/4000, Loss: 5.5636, Best Loss: 5.5424
# Epoch 1860/4000, Loss: 5.5719, Best Loss: 5.5424
# Epoch 1870/4000, Loss: 5.5568, Best Loss: 5.5424
# Epoch 1880/4000, Loss: 5.5629, Best Loss: 5.5424
# Epoch 1890/4000, Loss: 5.5826, Best Loss: 5.5410
# Epoch 1900/4000, Loss: 5.5609, Best Loss: 5.5410
# Epoch 1910/4000, Loss: 5.5475, Best Loss: 5.5410
# Epoch 1920/4000, Loss: 5.5362, Best Loss: 5.5330
# Epoch 1930/4000, Loss: 5.5444, Best Loss: 5.5214
# Epoch 1940/4000, Loss: 5.5830, Best Loss: 5.5214
# Epoch 1950/4000, Loss: 5.5625, Best Loss: 5.5214
# Epoch 1960/4000, Loss: 5.5535, Best Loss: 5.5214
# Epoch 1970/4000, Loss: 5.5363, Best Loss: 5.5214
# Epoch 1980/4000, Loss: 5.5492, Best Loss: 5.5173
# Epoch 1990/4000, Loss: 5.5448, Best Loss: 5.5078
# Epoch 2000/4000, Loss: 5.5551, Best Loss: 5.5078
# Epoch 2010/4000, Loss: 5.5906, Best Loss: 5.5078
# Epoch 2020/4000, Loss: 5.5330, Best Loss: 5.5063
# Epoch 2030/4000, Loss: 5.5457, Best Loss: 5.5063
# Epoch 2040/4000, Loss: 5.5241, Best Loss: 5.5063
# Epoch 2050/4000, Loss: 5.5363, Best Loss: 5.5063
# Epoch 2060/4000, Loss: 5.5151, Best Loss: 5.5063
# Epoch 2070/4000, Loss: 5.5494, Best Loss: 5.5063
# Epoch 2080/4000, Loss: 5.5234, Best Loss: 5.5041
# Epoch 2090/4000, Loss: 5.5451, Best Loss: 5.4978
# Epoch 2100/4000, Loss: 5.5160, Best Loss: 5.4978
# Epoch 2110/4000, Loss: 5.5527, Best Loss: 5.4978
# Epoch 2120/4000, Loss: 5.5270, Best Loss: 5.4978
# Epoch 2130/4000, Loss: 5.5170, Best Loss: 5.4942
# Epoch 2140/4000, Loss: 5.5199, Best Loss: 5.4942
# Epoch 2150/4000, Loss: 5.5362, Best Loss: 5.4942
# Epoch 2160/4000, Loss: 5.5000, Best Loss: 5.4942
# Epoch 2170/4000, Loss: 5.5081, Best Loss: 5.4942
# Epoch 2180/4000, Loss: 5.5354, Best Loss: 5.4942
# Epoch 2190/4000, Loss: 5.5286, Best Loss: 5.4942
# Epoch 2200/4000, Loss: 5.5241, Best Loss: 5.4835
# Epoch 2210/4000, Loss: 5.5026, Best Loss: 5.4835
# Epoch 2220/4000, Loss: 5.5139, Best Loss: 5.4692
# Epoch 2230/4000, Loss: 5.5001, Best Loss: 5.4692
# Epoch 2240/4000, Loss: 5.4780, Best Loss: 5.4692
# Epoch 2250/4000, Loss: 5.5035, Best Loss: 5.4692
# Epoch 2260/4000, Loss: 5.4627, Best Loss: 5.4607
# Epoch 2270/4000, Loss: 5.4908, Best Loss: 5.4607
# Epoch 2280/4000, Loss: 5.4910, Best Loss: 5.4607
# Epoch 2290/4000, Loss: 5.4880, Best Loss: 5.4607
# Epoch 2300/4000, Loss: 5.4751, Best Loss: 5.4379
# Epoch 2310/4000, Loss: 5.4461, Best Loss: 5.4379
# Epoch 2320/4000, Loss: 5.5049, Best Loss: 5.4379
# Epoch 2330/4000, Loss: 5.4792, Best Loss: 5.4379
# Epoch 2340/4000, Loss: 5.5012, Best Loss: 5.4379
# Epoch 2350/4000, Loss: 5.4851, Best Loss: 5.4379
# Epoch 2360/4000, Loss: 5.4649, Best Loss: 5.4379
# Epoch 2370/4000, Loss: 5.5045, Best Loss: 5.4379
# Epoch 2380/4000, Loss: 5.4831, Best Loss: 5.4379
# Epoch 2390/4000, Loss: 5.4632, Best Loss: 5.4379
# Epoch 2400/4000, Loss: 5.4628, Best Loss: 5.4379
# Epoch 2410/4000, Loss: 5.4405, Best Loss: 5.4379
# Epoch 2420/4000, Loss: 5.4855, Best Loss: 5.4379
# Epoch 2430/4000, Loss: 5.5161, Best Loss: 5.4258
# Epoch 2440/4000, Loss: 5.4700, Best Loss: 5.4258
# Epoch 2450/4000, Loss: 5.4838, Best Loss: 5.4258
# Epoch 2460/4000, Loss: 5.4868, Best Loss: 5.4258
# Epoch 2470/4000, Loss: 5.4537, Best Loss: 5.4258
# Epoch 2480/4000, Loss: 5.4868, Best Loss: 5.4258
# Epoch 2490/4000, Loss: 5.4438, Best Loss: 5.4258
# Epoch 2500/4000, Loss: 5.4436, Best Loss: 5.4258
# Epoch 2510/4000, Loss: 5.4748, Best Loss: 5.4258
# Epoch 2520/4000, Loss: 5.4678, Best Loss: 5.4258
# Epoch 2530/4000, Loss: 5.4731, Best Loss: 5.4105
# Epoch 2540/4000, Loss: 5.4245, Best Loss: 5.4105
# Epoch 2550/4000, Loss: 5.4255, Best Loss: 5.4105
# Epoch 2560/4000, Loss: 5.4655, Best Loss: 5.4105
# Epoch 2570/4000, Loss: 5.4409, Best Loss: 5.4105
# Epoch 2580/4000, Loss: 5.4536, Best Loss: 5.4105
# Epoch 2590/4000, Loss: 5.4232, Best Loss: 5.4105
# Epoch 2600/4000, Loss: 5.4345, Best Loss: 5.4105
# Epoch 2610/4000, Loss: 5.4247, Best Loss: 5.4011
# Epoch 2620/4000, Loss: 5.4163, Best Loss: 5.4011
# Epoch 2630/4000, Loss: 5.4257, Best Loss: 5.3861
# Epoch 2640/4000, Loss: 5.4338, Best Loss: 5.3861
# Epoch 2650/4000, Loss: 5.4303, Best Loss: 5.3861
# Epoch 2660/4000, Loss: 5.4047, Best Loss: 5.3861
# Epoch 2670/4000, Loss: 5.4467, Best Loss: 5.3861
# Epoch 2680/4000, Loss: 5.4324, Best Loss: 5.3861
# Epoch 2690/4000, Loss: 5.4196, Best Loss: 5.3747
# Epoch 2700/4000, Loss: 5.4484, Best Loss: 5.3747
# Epoch 2710/4000, Loss: 5.4357, Best Loss: 5.3747
# Epoch 2720/4000, Loss: 5.4311, Best Loss: 5.3747
# Epoch 2730/4000, Loss: 5.4379, Best Loss: 5.3747
# Epoch 2740/4000, Loss: 5.4269, Best Loss: 5.3736
# Epoch 2750/4000, Loss: 5.4232, Best Loss: 5.3736
# Epoch 2760/4000, Loss: 5.3923, Best Loss: 5.3736
# Epoch 2770/4000, Loss: 5.4159, Best Loss: 5.3702
# Epoch 2780/4000, Loss: 5.4405, Best Loss: 5.3702
# Epoch 2790/4000, Loss: 5.4077, Best Loss: 5.3702
# Epoch 2800/4000, Loss: 5.4185, Best Loss: 5.3702
# Epoch 2810/4000, Loss: 5.4106, Best Loss: 5.3702
# Epoch 2820/4000, Loss: 5.4002, Best Loss: 5.3702
# Epoch 2830/4000, Loss: 5.4202, Best Loss: 5.3702
# Epoch 2840/4000, Loss: 5.4119, Best Loss: 5.3702
# Epoch 2850/4000, Loss: 5.3686, Best Loss: 5.3686
# Epoch 2860/4000, Loss: 5.4113, Best Loss: 5.3686
# Epoch 2870/4000, Loss: 5.4283, Best Loss: 5.3686
# Epoch 2880/4000, Loss: 5.4121, Best Loss: 5.3450
# Epoch 2890/4000, Loss: 5.3886, Best Loss: 5.3450
# Epoch 2900/4000, Loss: 5.3858, Best Loss: 5.3435
# Epoch 2910/4000, Loss: 5.4171, Best Loss: 5.3435
# Epoch 2920/4000, Loss: 5.3542, Best Loss: 5.3435
# Epoch 2930/4000, Loss: 5.3934, Best Loss: 5.3435
# Epoch 2940/4000, Loss: 5.3553, Best Loss: 5.3342
# Epoch 2950/4000, Loss: 5.3888, Best Loss: 5.3342
# Epoch 2960/4000, Loss: 5.3767, Best Loss: 5.3342
# Epoch 2970/4000, Loss: 5.3960, Best Loss: 5.3342
# Epoch 2980/4000, Loss: 5.4026, Best Loss: 5.3342
# Epoch 2990/4000, Loss: 5.3544, Best Loss: 5.3342
# Epoch 3000/4000, Loss: 5.3914, Best Loss: 5.3300
# Epoch 3010/4000, Loss: 5.3571, Best Loss: 5.3300
# Epoch 3020/4000, Loss: 5.3887, Best Loss: 5.3177
# Epoch 3030/4000, Loss: 5.3690, Best Loss: 5.3177
# Epoch 3040/4000, Loss: 5.3584, Best Loss: 5.3177
# Epoch 3050/4000, Loss: 5.3909, Best Loss: 5.3177
# Epoch 3060/4000, Loss: 5.4049, Best Loss: 5.3177
# Epoch 3070/4000, Loss: 5.3802, Best Loss: 5.3177
# Epoch 3080/4000, Loss: 5.3826, Best Loss: 5.3177
# Epoch 3090/4000, Loss: 5.3440, Best Loss: 5.3177
# Epoch 3100/4000, Loss: 5.3775, Best Loss: 5.3177
# Epoch 3110/4000, Loss: 5.3588, Best Loss: 5.3025
# Epoch 3120/4000, Loss: 5.3707, Best Loss: 5.3025
# Epoch 3130/4000, Loss: 5.4413, Best Loss: 5.3025
# Epoch 3140/4000, Loss: 5.4058, Best Loss: 5.3025
# Epoch 3150/4000, Loss: 5.3672, Best Loss: 5.3025
# Epoch 3160/4000, Loss: 5.3600, Best Loss: 5.3025
# Epoch 3170/4000, Loss: 5.3487, Best Loss: 5.3025
# Epoch 3180/4000, Loss: 5.3302, Best Loss: 5.3025
# Epoch 3190/4000, Loss: 5.3397, Best Loss: 5.3025
# Epoch 3200/4000, Loss: 5.4288, Best Loss: 5.3025
# Epoch 3210/4000, Loss: 5.3394, Best Loss: 5.3025
# Epoch 3220/4000, Loss: 5.3425, Best Loss: 5.2796
# Epoch 3230/4000, Loss: 5.3093, Best Loss: 5.2796
# Epoch 3240/4000, Loss: 5.3196, Best Loss: 5.2796
# Epoch 3250/4000, Loss: 5.3365, Best Loss: 5.2796
# Epoch 3260/4000, Loss: 5.3272, Best Loss: 5.2796
# Epoch 3270/4000, Loss: 5.3248, Best Loss: 5.2796
# Epoch 3280/4000, Loss: 5.3446, Best Loss: 5.2796
# Epoch 3290/4000, Loss: 5.3468, Best Loss: 5.2796
# Epoch 3300/4000, Loss: 5.3392, Best Loss: 5.2796
# Epoch 3310/4000, Loss: 5.3420, Best Loss: 5.2796
# Epoch 3320/4000, Loss: 5.3077, Best Loss: 5.2796
# Epoch 3330/4000, Loss: 5.3554, Best Loss: 5.2796
# Epoch 3340/4000, Loss: 5.3248, Best Loss: 5.2796
# Epoch 3350/4000, Loss: 5.3214, Best Loss: 5.2796
# Epoch 3360/4000, Loss: 5.2969, Best Loss: 5.2796
# Epoch 3370/4000, Loss: 5.3547, Best Loss: 5.2796
# Epoch 3380/4000, Loss: 5.3066, Best Loss: 5.2760
# Epoch 3390/4000, Loss: 5.3055, Best Loss: 5.2760
# Epoch 3400/4000, Loss: 5.2923, Best Loss: 5.2760
# Epoch 3410/4000, Loss: 5.3206, Best Loss: 5.2760
# Epoch 3420/4000, Loss: 5.3145, Best Loss: 5.2760
# Epoch 3430/4000, Loss: 5.3905, Best Loss: 5.2760
# Epoch 3440/4000, Loss: 5.3358, Best Loss: 5.2760
# Epoch 3450/4000, Loss: 5.2904, Best Loss: 5.2760
# Epoch 3460/4000, Loss: 5.2632, Best Loss: 5.2632
# Epoch 3470/4000, Loss: 5.3060, Best Loss: 5.2632
# Epoch 3480/4000, Loss: 5.3095, Best Loss: 5.2632
# Epoch 3490/4000, Loss: 5.2720, Best Loss: 5.2632
# Epoch 3500/4000, Loss: 5.3026, Best Loss: 5.2632
# Epoch 3510/4000, Loss: 5.3102, Best Loss: 5.2632
# Epoch 3520/4000, Loss: 5.3049, Best Loss: 5.2632
# Epoch 3530/4000, Loss: 5.2983, Best Loss: 5.2632
# Epoch 3540/4000, Loss: 5.3243, Best Loss: 5.2628
# Epoch 3550/4000, Loss: 5.2769, Best Loss: 5.2628
# Epoch 3560/4000, Loss: 5.2963, Best Loss: 5.2628
# Epoch 3570/4000, Loss: 5.2920, Best Loss: 5.2628
# Epoch 3580/4000, Loss: 5.3115, Best Loss: 5.2628
# Epoch 3590/4000, Loss: 5.2929, Best Loss: 5.2628
# Epoch 3600/4000, Loss: 5.2712, Best Loss: 5.2628
# Epoch 3610/4000, Loss: 5.3163, Best Loss: 5.2617
# Epoch 3620/4000, Loss: 5.2582, Best Loss: 5.2582
# Epoch 3630/4000, Loss: 5.3105, Best Loss: 5.2268
# Epoch 3640/4000, Loss: 5.2886, Best Loss: 5.2268
# Epoch 3650/4000, Loss: 5.3034, Best Loss: 5.2268
# Epoch 3660/4000, Loss: 5.3060, Best Loss: 5.2268
# Epoch 3670/4000, Loss: 5.2857, Best Loss: 5.2268
# Epoch 3680/4000, Loss: 5.2985, Best Loss: 5.2268
# Epoch 3690/4000, Loss: 5.2573, Best Loss: 5.2268
# Epoch 3700/4000, Loss: 5.2895, Best Loss: 5.2268
# Epoch 3710/4000, Loss: 5.2773, Best Loss: 5.2268
# Epoch 3720/4000, Loss: 5.3087, Best Loss: 5.2268
# Epoch 3730/4000, Loss: 5.2645, Best Loss: 5.2268
# Epoch 3740/4000, Loss: 5.2093, Best Loss: 5.2093
# Epoch 3750/4000, Loss: 5.2463, Best Loss: 5.2093
# Epoch 3760/4000, Loss: 5.2778, Best Loss: 5.2093
# Epoch 3770/4000, Loss: 5.3073, Best Loss: 5.2093
# Epoch 3780/4000, Loss: 5.3021, Best Loss: 5.2093
# Epoch 3790/4000, Loss: 5.2482, Best Loss: 5.2093
# Epoch 3800/4000, Loss: 5.2694, Best Loss: 5.2093
# Epoch 3810/4000, Loss: 5.2798, Best Loss: 5.2093
# Epoch 3820/4000, Loss: 5.2798, Best Loss: 5.2040
# Epoch 3830/4000, Loss: 5.2550, Best Loss: 5.2040
# Epoch 3840/4000, Loss: 5.2421, Best Loss: 5.2040
# Epoch 3850/4000, Loss: 5.2786, Best Loss: 5.2040
# Epoch 3860/4000, Loss: 5.2716, Best Loss: 5.2040
# Epoch 3870/4000, Loss: 5.2871, Best Loss: 5.2040
# Epoch 3880/4000, Loss: 5.2465, Best Loss: 5.2040
# Epoch 3890/4000, Loss: 5.2428, Best Loss: 5.2040
# Epoch 3900/4000, Loss: 5.3161, Best Loss: 5.2040
# Epoch 3910/4000, Loss: 5.3084, Best Loss: 5.2040
# Epoch 3920/4000, Loss: 5.2673, Best Loss: 5.2040
# Epoch 3930/4000, Loss: 5.2381, Best Loss: 5.2040
# Epoch 3940/4000, Loss: 5.2241, Best Loss: 5.2040
# Epoch 3950/4000, Loss: 5.2726, Best Loss: 5.2040
# Epoch 3960/4000, Loss: 5.2119, Best Loss: 5.2018
# Epoch 3970/4000, Loss: 5.2592, Best Loss: 5.2018
# Epoch 3980/4000, Loss: 5.2582, Best Loss: 5.2018
# Epoch 3990/4000, Loss: 5.2581, Best Loss: 5.2018
# Epoch 4000/4000, Loss: 5.2390, Best Loss: 5.2018
# Lowest Risk (Q1) size: 200
# Q2 size: 200
# Q3 size: 200
# Q4 size: 200
# Highest Risk (Q5) size: 200
# Lowest Risk (Q1) size: 200
# Q2 size: 200
# Q3 size: 200
# Q4 size: 200
# Highest Risk (Q5) size: 200

# %% [markdown]
# ## 1. Simple loghazard model

# %%
# Prepare data for PyTorch
X = torch.FloatTensor(survival_data[feature_cols].values)
times = torch.FloatTensor(survival_data['observed_time'].values)
events = torch.FloatTensor(survival_data['event_observed'].values)

# Create data loader
dataset = TensorDataset(X, times, events)
batch_size = X.shape[0]  # Use the entire dataset as one batch
train_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# Initialize model and optimizer
model = LogHazardModel(len(feature_cols))
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
# Training loop
def train_epoch(model, train_loader, optimizer):
    model.train()
    total_loss = 0
    
    for X_batch, times_batch, events_batch in train_loader:
        optimizer.zero_grad()
        
        # Get log hazards
        log_hazards = model(X_batch)
        
        # Calculate loss
        loss = tscox.neg_partial_log_likelihood(log_hazards, events_batch==1, times_batch, ties_method='efron', reduction = reduction)
        
        # # Basic implementation of cox partial likelihood
        # log_risk = log_hazards
        # risk = torch.exp(log_risk)
        
        # # Sort by time
        # sorted_times, sort_idx = torch.sort(times_batch, descending=True)
        # risk = risk[sort_idx]
        # events = events_batch[sort_idx]
        
        # # Calculate loss using cox partial likelihood
        # log_cumsum = torch.log(torch.cumsum(risk, dim=0) + 1e-8)
        # loss = -torch.mean((log_risk[events == 1] - log_cumsum[events == 1]))
        
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
    
    return total_loss / len(train_loader)

# Train the model
n_epochs = 100
losses = []

for epoch in range(n_epochs):
    loss = train_epoch(model, train_loader, optimizer)
    losses.append(loss)
    if (epoch + 1) % 10 == 0:
        print(f'Epoch {epoch+1}/{n_epochs}, Loss: {loss:.4f}')

# Plot training loss
plt.figure(figsize=(10, 6))
plt.plot(losses)
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
# Out:
# C:\Users\ericf\Github\torchsurv\src\torchsurv\loss\cox.py:138: UserWarning: Ties in event time detected; using efron's method to handle ties.
#   warnings.warn(
# Epoch 10/100, Loss: 6.0253
# Epoch 20/100, Loss: 6.0249
# Epoch 30/100, Loss: 6.0269
# Epoch 40/100, Loss: 6.0189
# Epoch 50/100, Loss: 6.0194
# Epoch 60/100, Loss: 6.0118
# Epoch 70/100, Loss: 6.0070
# Epoch 80/100, Loss: 6.0087
# Epoch 90/100, Loss: 5.9958
# Epoch 100/100, Loss: 5.9904

# %% [markdown]
# ## 2. Ukko model

# %% [markdown]
# ## 2. Ukko Model
#
# Now we'll train a DualAttentionRegressor model from the ukko package and compare its performance.

# %%
import importlib
import ukko.core
#from ukko.core import UkkoLogHazardModel, train_model_simple
importlib.reload(ukko.core)

# Example usage (replace existing training loop):
model = LogHazardModel(len(feature_cols))
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
reduction = 'mean'

# Usage: UkkoLogHazardModel:
model = ukko.core.UkkoLogHazardModel(len(feature_cols))
optimizer = torch.optim.Adam(model.parameters(), lr=0.0002)
reduction = 'mean'

# Train the model
model, history, best_loss = train_model_simple(
    model, train_loader, optimizer,
    n_epochs=10,
    device='gpu',
    reduction=reduction
)

# Plot training loss
plt.figure(figsize=(10, 6))
plt.plot(history['train_loss'])
plt.axhline(y=best_loss, color='r', linestyle='--', label='Best Loss')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Model performance evaluation:
# Generate risk scores using the trained model
model.eval()
with torch.no_grad():
    risk_scores, feat_weights, time_weights = model(X)
    risk_scores = risk_scores.numpy()

# Create stratification plot
cutoffs = stratify_and_plot(survival_data, risk_scores, n_groups=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4 importlib.reload(ukko.core)
#       6 # Example usage (replace existing training loop):
# ----> 7 model = LogHazardModel(len(feature_cols))
#       8 optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
#       9 reduction = 'mean'
#
# NameError: name 'LogHazardModel' is not defined

# %%
# Generate risk scores using the trained model
model.eval()
with torch.no_grad():
    risk_scores, feat_weights, time_weights = model(X)
    risk_scores = risk_scores.numpy()

# Create stratification plot
cutoffs = stratify_and_plot(survival_data, risk_scores, n_groups=5)

# Visualize attention weights
plt.figure(figsize=(10, 4))

# Feature attention weights - reshape for visualization
feat_attention = feat_weights.detach().numpy()
feat_attention = feat_attention.reshape(-1, len(feature_cols))  # Reshape to [batch*heads, n_features]

plt.subplot(121)
plt.imshow(feat_attention, aspect='auto')
plt.title('Feature Attention Weights')
plt.colorbar()
plt.xlabel('Features')
plt.ylabel('Batch × Heads')

# Time attention weights - should be 1×1 for our case
plt.subplot(122)
time_attention = time_weights.detach().numpy()
time_attention = time_attention.reshape(-1, 1)  # Reshape to [batch*heads, 1]

plt.imshow(time_attention, aspect='auto')
plt.title('Time Attention Weights')
plt.colorbar()
plt.xlabel('Time Step')
plt.ylabel('Batch × Heads')

plt.tight_layout()
plt.show()

# Print average feature attention weights
mean_attention = feat_attention.mean(axis=0)
plt.figure(figsize=(10, 4))
plt.bar(range(len(feature_cols)), mean_attention)
plt.title('Average Feature Importance')
plt.xlabel('Feature Index')
plt.ylabel('Mean Attention Weight')
plt.xticks(range(len(feature_cols)), feature_cols, rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Lowest Risk (Q1) size: 200
# Q2 size: 200
# Q3 size: 200
# Q4 size: 200
# Highest Risk (Q5) size: 200

# %% [markdown]
# # Appendix - depreciated stuff

# %%
from ukko.core import DualAttentionRegressor1
import copy 


# Define the Ukko LogHazard model
class UkkoLogHazardModel(nn.Module):
    def __init__(self, n_features):
        super().__init__()
        self.attention_net = DualAttentionRegressor1(
            n_features=n_features,
            time_steps=1,  # Since we're using instantaneous inputs
            d_model=64,
            n_heads=4,
            dropout=0.1,
            n_modules=3
        )
    
    def forward(self, x):
        # Add time dimension expected by DualAttentionRegressor
        x = x.unsqueeze(2)  # [batch_size, n_features, 1]
        
        # Get predictions from attention network
        predictions, feat_weights, time_weights = self.attention_net(x)
        
        return predictions, feat_weights, time_weights

# Initialize model and optimizer
model = UkkoLogHazardModel(len(feature_cols))
optimizer = torch.optim.Adam(model.parameters(), lr=0.0002)

# Training loop
n_epochs = 600  # Increased epochs since we're tracking best model
losses = []
best_loss = float('inf')
best_model_state = None

for epoch in range(n_epochs):
    # Adjust learning rate after 300 epochs
    if epoch == 300:
        for param_group in optimizer.param_groups:
            param_group['lr'] = 0.001

    model.train()
    total_loss = 0
    
    for X_batch, times_batch, events_batch in train_loader:
        optimizer.zero_grad()
        
        # Get log hazards
        log_hazards, feat_weights, time_weights = model(X_batch)
        
        # Calculate loss using TorchSurv's Cox partial likelihood
        loss = tscox.neg_partial_log_likelihood(log_hazards, events_batch==1, times_batch, ties_method='efron', reduction='mean')
        
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
    
    avg_loss = total_loss / len(train_loader)
    losses.append(avg_loss)
    
    # Save best model
    if avg_loss < best_loss:
        best_loss = avg_loss
        best_model_state = copy.deepcopy(model.state_dict())
    
    if (epoch + 1) % 3 == 0:
        print(f'Epoch {epoch+1}/{n_epochs}, Loss: {avg_loss:.4f}, Best Loss: {best_loss:.4f}')

# Plot training loss
plt.figure(figsize=(10, 6))
plt.plot(losses)
plt.axhline(y=best_loss, color='r', linestyle='--', label='Best Loss')
plt.title('Training Loss - Ukko LogHazard Model')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Load best model for evaluation
print('\nLoading best model with loss:', best_loss)
model.load_state_dict(best_model_state)
# Out:
# C:\Users\ericf\Github\torchsurv\src\torchsurv\loss\cox.py:138: UserWarning: Ties in event time detected; using efron's method to handle ties.
#   warnings.warn(
# Epoch 3/600, Loss: 6.0313, Best Loss: 6.0313
# Epoch 6/600, Loss: 6.0276, Best Loss: 6.0276
# Epoch 9/600, Loss: 6.0274, Best Loss: 6.0274
# Epoch 12/600, Loss: 6.0265, Best Loss: 6.0265
# Epoch 15/600, Loss: 6.0244, Best Loss: 6.0244
# Epoch 18/600, Loss: 6.0270, Best Loss: 6.0244
# Epoch 21/600, Loss: 6.0246, Best Loss: 6.0240
# Epoch 24/600, Loss: 6.0227, Best Loss: 6.0227
# Epoch 27/600, Loss: 6.0209, Best Loss: 6.0209
# Epoch 30/600, Loss: 6.0267, Best Loss: 6.0209
# Epoch 33/600, Loss: 6.0316, Best Loss: 6.0201
# Epoch 36/600, Loss: 6.0201, Best Loss: 6.0201
# Epoch 39/600, Loss: 6.0237, Best Loss: 6.0171
# Epoch 42/600, Loss: 6.0218, Best Loss: 6.0171
# Epoch 45/600, Loss: 6.0201, Best Loss: 6.0171
# Epoch 48/600, Loss: 6.0198, Best Loss: 6.0171
# Epoch 51/600, Loss: 6.0211, Best Loss: 6.0163
# Epoch 54/600, Loss: 6.0193, Best Loss: 6.0163
# Epoch 57/600, Loss: 6.0225, Best Loss: 6.0163
# Epoch 60/600, Loss: 6.0170, Best Loss: 6.0143
# Epoch 63/600, Loss: 6.0198, Best Loss: 6.0143
# Epoch 66/600, Loss: 6.0165, Best Loss: 6.0114
# Epoch 69/600, Loss: 6.0122, Best Loss: 6.0114
# Epoch 72/600, Loss: 6.0095, Best Loss: 6.0087
# Epoch 75/600, Loss: 6.0082, Best Loss: 6.0082
# Epoch 78/600, Loss: 6.0105, Best Loss: 6.0082
# Epoch 81/600, Loss: 6.0114, Best Loss: 6.0055
# Epoch 84/600, Loss: 6.0020, Best Loss: 6.0020
# Epoch 87/600, Loss: 6.0033, Best Loss: 6.0020
# Epoch 90/600, Loss: 6.0031, Best Loss: 6.0020
# Epoch 93/600, Loss: 5.9993, Best Loss: 5.9993
# Epoch 96/600, Loss: 6.0060, Best Loss: 5.9976
# Epoch 99/600, Loss: 6.0041, Best Loss: 5.9976
# Epoch 102/600, Loss: 5.9993, Best Loss: 5.9976
# Epoch 105/600, Loss: 6.0026, Best Loss: 5.9975
# Epoch 108/600, Loss: 6.0019, Best Loss: 5.9959
# Epoch 111/600, Loss: 5.9985, Best Loss: 5.9959
# Epoch 114/600, Loss: 6.0017, Best Loss: 5.9959
# Epoch 117/600, Loss: 5.9996, Best Loss: 5.9959
# Epoch 120/600, Loss: 5.9953, Best Loss: 5.9953
# Epoch 123/600, Loss: 5.9978, Best Loss: 5.9941
# Epoch 126/600, Loss: 5.9974, Best Loss: 5.9934
# Epoch 129/600, Loss: 5.9957, Best Loss: 5.9934
# Epoch 132/600, Loss: 5.9885, Best Loss: 5.9885
# Epoch 135/600, Loss: 5.9910, Best Loss: 5.9885
# Epoch 138/600, Loss: 5.9899, Best Loss: 5.9885
# Epoch 141/600, Loss: 5.9980, Best Loss: 5.9884
# Epoch 144/600, Loss: 5.9963, Best Loss: 5.9869
# Epoch 147/600, Loss: 5.9907, Best Loss: 5.9869
# Epoch 150/600, Loss: 5.9942, Best Loss: 5.9869
# Epoch 153/600, Loss: 5.9889, Best Loss: 5.9817
# Epoch 156/600, Loss: 5.9837, Best Loss: 5.9817
# Epoch 159/600, Loss: 5.9909, Best Loss: 5.9817
# Epoch 162/600, Loss: 5.9940, Best Loss: 5.9775
# Epoch 165/600, Loss: 5.9897, Best Loss: 5.9775
# Epoch 168/600, Loss: 5.9937, Best Loss: 5.9775
# Epoch 171/600, Loss: 5.9852, Best Loss: 5.9775
# Epoch 174/600, Loss: 5.9824, Best Loss: 5.9775
# Epoch 177/600, Loss: 5.9786, Best Loss: 5.9775
# Epoch 180/600, Loss: 5.9754, Best Loss: 5.9754
# Epoch 183/600, Loss: 5.9883, Best Loss: 5.9754
# Epoch 186/600, Loss: 5.9804, Best Loss: 5.9754
# Epoch 189/600, Loss: 5.9842, Best Loss: 5.9754
# Epoch 192/600, Loss: 5.9727, Best Loss: 5.9727
# Epoch 195/600, Loss: 5.9772, Best Loss: 5.9727
# Epoch 198/600, Loss: 5.9844, Best Loss: 5.9727
# Epoch 201/600, Loss: 5.9884, Best Loss: 5.9727
# Epoch 204/600, Loss: 5.9737, Best Loss: 5.9727
# Epoch 207/600, Loss: 5.9804, Best Loss: 5.9727
# Epoch 210/600, Loss: 5.9768, Best Loss: 5.9727
# Epoch 213/600, Loss: 5.9655, Best Loss: 5.9655
# Epoch 216/600, Loss: 5.9809, Best Loss: 5.9655
# Epoch 219/600, Loss: 5.9792, Best Loss: 5.9655
# Epoch 222/600, Loss: 5.9663, Best Loss: 5.9655
# Epoch 225/600, Loss: 5.9711, Best Loss: 5.9655
# Epoch 228/600, Loss: 5.9718, Best Loss: 5.9613
# Epoch 231/600, Loss: 5.9666, Best Loss: 5.9613
# Epoch 234/600, Loss: 5.9725, Best Loss: 5.9613
# Epoch 237/600, Loss: 5.9672, Best Loss: 5.9613
# Epoch 240/600, Loss: 5.9687, Best Loss: 5.9609
# Epoch 243/600, Loss: 5.9670, Best Loss: 5.9609
# Epoch 246/600, Loss: 5.9668, Best Loss: 5.9609
# Epoch 249/600, Loss: 5.9649, Best Loss: 5.9609
# Epoch 252/600, Loss: 5.9709, Best Loss: 5.9608
# Epoch 255/600, Loss: 5.9612, Best Loss: 5.9608
# Epoch 258/600, Loss: 5.9662, Best Loss: 5.9608
# Epoch 261/600, Loss: 5.9716, Best Loss: 5.9608
# Epoch 264/600, Loss: 5.9670, Best Loss: 5.9606
# Epoch 267/600, Loss: 5.9777, Best Loss: 5.9606
# Epoch 270/600, Loss: 5.9584, Best Loss: 5.9584
# Epoch 273/600, Loss: 5.9708, Best Loss: 5.9584
# Epoch 276/600, Loss: 5.9669, Best Loss: 5.9584
# Epoch 279/600, Loss: 5.9771, Best Loss: 5.9584
# Epoch 282/600, Loss: 5.9528, Best Loss: 5.9528
# Epoch 285/600, Loss: 5.9670, Best Loss: 5.9528
# Epoch 288/600, Loss: 5.9567, Best Loss: 5.9528
# Epoch 291/600, Loss: 5.9657, Best Loss: 5.9528
# Epoch 294/600, Loss: 5.9588, Best Loss: 5.9528
# Epoch 297/600, Loss: 5.9660, Best Loss: 5.9528
# Epoch 300/600, Loss: 5.9562, Best Loss: 5.9528
# Epoch 303/600, Loss: 5.9724, Best Loss: 5.9528
# Epoch 306/600, Loss: 5.9699, Best Loss: 5.9528
# Epoch 309/600, Loss: 5.9809, Best Loss: 5.9528
# Epoch 312/600, Loss: 5.9685, Best Loss: 5.9528
# Epoch 315/600, Loss: 5.9661, Best Loss: 5.9528
# Epoch 318/600, Loss: 5.9765, Best Loss: 5.9528
# Epoch 321/600, Loss: 5.9634, Best Loss: 5.9528
# Epoch 324/600, Loss: 5.9625, Best Loss: 5.9528
# Epoch 327/600, Loss: 5.9639, Best Loss: 5.9528
# Epoch 330/600, Loss: 5.9557, Best Loss: 5.9522
# Epoch 333/600, Loss: 5.9602, Best Loss: 5.9522
# Epoch 336/600, Loss: 5.9552, Best Loss: 5.9466
# Epoch 339/600, Loss: 5.9541, Best Loss: 5.9462
# Epoch 342/600, Loss: 5.9475, Best Loss: 5.9462
# Epoch 345/600, Loss: 5.9619, Best Loss: 5.9462
# Epoch 348/600, Loss: 5.9569, Best Loss: 5.9462
# Epoch 351/600, Loss: 5.9677, Best Loss: 5.9461
# Epoch 354/600, Loss: 5.9514, Best Loss: 5.9461
# Epoch 357/600, Loss: 5.9415, Best Loss: 5.9415
# Epoch 360/600, Loss: 5.9455, Best Loss: 5.9415
# Epoch 363/600, Loss: 5.9445, Best Loss: 5.9402
# Epoch 366/600, Loss: 5.9390, Best Loss: 5.9390
# Epoch 369/600, Loss: 5.9356, Best Loss: 5.9356
# Epoch 372/600, Loss: 5.9245, Best Loss: 5.9245
# Epoch 375/600, Loss: 5.9350, Best Loss: 5.9245
# Epoch 378/600, Loss: 5.9345, Best Loss: 5.9245
# Epoch 381/600, Loss: 5.9334, Best Loss: 5.9245
# Epoch 384/600, Loss: 5.9365, Best Loss: 5.9245
# Epoch 387/600, Loss: 5.9363, Best Loss: 5.9245
# Epoch 390/600, Loss: 5.9456, Best Loss: 5.9245
# Epoch 393/600, Loss: 5.9461, Best Loss: 5.9245
# Epoch 396/600, Loss: 5.9439, Best Loss: 5.9245
# Epoch 399/600, Loss: 5.9484, Best Loss: 5.9245
# Epoch 402/600, Loss: 5.9285, Best Loss: 5.9245
# Epoch 405/600, Loss: 5.9296, Best Loss: 5.9181
# Epoch 408/600, Loss: 5.9211, Best Loss: 5.9181
# Epoch 411/600, Loss: 5.9419, Best Loss: 5.9181
# Epoch 414/600, Loss: 5.9044, Best Loss: 5.9044
# Epoch 417/600, Loss: 5.9320, Best Loss: 5.9044
# Epoch 420/600, Loss: 5.9443, Best Loss: 5.9044
# Epoch 423/600, Loss: 5.9360, Best Loss: 5.9044
# Epoch 426/600, Loss: 5.9146, Best Loss: 5.9044
# Epoch 429/600, Loss: 5.9096, Best Loss: 5.9044
# Epoch 432/600, Loss: 5.9119, Best Loss: 5.8992
# Epoch 435/600, Loss: 5.9106, Best Loss: 5.8992
# Epoch 438/600, Loss: 5.9256, Best Loss: 5.8992
# Epoch 441/600, Loss: 5.9267, Best Loss: 5.8992
# Epoch 444/600, Loss: 5.9128, Best Loss: 5.8992
# Epoch 447/600, Loss: 5.8958, Best Loss: 5.8958
# Epoch 450/600, Loss: 5.8961, Best Loss: 5.8870
# Epoch 453/600, Loss: 5.8887, Best Loss: 5.8870
# Epoch 456/600, Loss: 5.8964, Best Loss: 5.8870
# Epoch 459/600, Loss: 5.9107, Best Loss: 5.8870
# Epoch 462/600, Loss: 5.8914, Best Loss: 5.8870
# Epoch 465/600, Loss: 5.8824, Best Loss: 5.8824
# Epoch 468/600, Loss: 5.8948, Best Loss: 5.8824
# Epoch 471/600, Loss: 5.8828, Best Loss: 5.8824
# Epoch 474/600, Loss: 5.9000, Best Loss: 5.8824
# Epoch 477/600, Loss: 5.8799, Best Loss: 5.8799
# Epoch 480/600, Loss: 5.9241, Best Loss: 5.8799
# Epoch 483/600, Loss: 5.9041, Best Loss: 5.8799
# Epoch 486/600, Loss: 5.9063, Best Loss: 5.8799
# Epoch 489/600, Loss: 5.8993, Best Loss: 5.8784
# Epoch 492/600, Loss: 5.8853, Best Loss: 5.8784
# Epoch 495/600, Loss: 5.8869, Best Loss: 5.8784
# Epoch 498/600, Loss: 5.8709, Best Loss: 5.8709
# Epoch 501/600, Loss: 5.8927, Best Loss: 5.8695
# Epoch 504/600, Loss: 5.8898, Best Loss: 5.8695
# Epoch 507/600, Loss: 5.9103, Best Loss: 5.8695
# Epoch 510/600, Loss: 5.9375, Best Loss: 5.8695
# Epoch 513/600, Loss: 5.9047, Best Loss: 5.8695
# Epoch 516/600, Loss: 5.9195, Best Loss: 5.8695
# Epoch 519/600, Loss: 5.8876, Best Loss: 5.8695
# Epoch 522/600, Loss: 5.8911, Best Loss: 5.8695
# Epoch 525/600, Loss: 5.8937, Best Loss: 5.8695
# Epoch 528/600, Loss: 5.8817, Best Loss: 5.8629
# Epoch 531/600, Loss: 5.8746, Best Loss: 5.8629
# Epoch 534/600, Loss: 5.8573, Best Loss: 5.8549
# Epoch 537/600, Loss: 5.8733, Best Loss: 5.8549
# Epoch 540/600, Loss: 5.8776, Best Loss: 5.8549
# Epoch 543/600, Loss: 5.8779, Best Loss: 5.8549
# Epoch 546/600, Loss: 5.9078, Best Loss: 5.8549
# Epoch 549/600, Loss: 5.9138, Best Loss: 5.8549
# Epoch 552/600, Loss: 5.8799, Best Loss: 5.8549
# Epoch 555/600, Loss: 5.8958, Best Loss: 5.8549
# Epoch 558/600, Loss: 5.8789, Best Loss: 5.8549
# Epoch 561/600, Loss: 5.8906, Best Loss: 5.8549
# Epoch 564/600, Loss: 5.8926, Best Loss: 5.8549
# Epoch 567/600, Loss: 5.8840, Best Loss: 5.8549
# Epoch 570/600, Loss: 5.8831, Best Loss: 5.8549
# Epoch 573/600, Loss: 5.8534, Best Loss: 5.8534
# Epoch 576/600, Loss: 5.8682, Best Loss: 5.8534
# Epoch 579/600, Loss: 5.8557, Best Loss: 5.8534
# Epoch 582/600, Loss: 5.8338, Best Loss: 5.8338
# Epoch 585/600, Loss: 5.8585, Best Loss: 5.8338
# Epoch 588/600, Loss: 5.8462, Best Loss: 5.8338
# Epoch 591/600, Loss: 5.8489, Best Loss: 5.8338
# Epoch 594/600, Loss: 5.8539, Best Loss: 5.8338
# Epoch 597/600, Loss: 5.8489, Best Loss: 5.8338
# Epoch 600/600, Loss: 5.8321, Best Loss: 5.8321
# Loading best model with loss: 5.83213472366333
# <All keys matched successfully>
